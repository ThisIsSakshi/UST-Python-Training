# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('C:/Users/User/Documents/BikeSharingData.csv')
data.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
data.shape
# Out:
# (731, 16)

# %%
data.isnull().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
print(data.columns)
# Out:
# Index(['instant', 'dteday', 'season', 'yr', 'mnth', 'holiday', 'weekday',
#        'workingday', 'weathersit', 'temp', 'atemp', 'hum', 'windspeed',
#        'casual', 'registered', 'cnt'],
#       dtype='object')

# %%
#1. Draw scatter plots for casual vs registered users
plt.scatter(data['casual'],data['registered'])
plt.xlabel('calsual')
plt.ylabel('registerd')
plt.show()

# %%
#2. Draw a histogram showing bike sharing data for various seasons
import numpy as np
import seaborn as sns
g = sns.FacetGrid(data,col="season", margin_titles=True)
g.map(plt.hist, "cnt", color="steelblue")
plt.show()

# %%
#3. Draw a histogram for various weather situations.
g = sns.FacetGrid(data,col="weathersit", margin_titles=True)
g.map(plt.hist, "cnt", color="steelblue")
plt.show()

# %%
#4. What features affect the bike sharing trends? Why?
#Season
g = sns.FacetGrid(data,col="season", margin_titles=True)
g.map(plt.hist, "cnt", color="steelblue")
plt.show()

# %%
#yr
g = sns.FacetGrid(data,col="yr", margin_titles=True)
g.map(plt.hist, "cnt", color="steelblue")
plt.show()

# %%
#mnth
g = sns.FacetGrid(data,"mnth", margin_titles=True)
sns.set(rc={'figure.figsize':(8,10)})
g.map(plt.hist, "cnt", color="steelblue")
plt.show()

# %%
#holiday
g = sns.FacetGrid(data,col="holiday", margin_titles=True)
sns.set(rc={'figure.figsize':(8,10)})
g.map(plt.hist, "cnt", color="steelblue")
plt.show()

# %%
#weekday
g = sns.FacetGrid(data,"weekday", margin_titles=True)
sns.set(rc={'figure.figsize':(8,10)})
g.map(plt.hist, "cnt", color="steelblue")
plt.show()

# %%
#weathersit
g = sns.FacetGrid(data,col="weathersit", margin_titles=True)
sns.set(rc={'figure.figsize':(8,10)})
g.map(plt.hist, "cnt", color="steelblue")
plt.show()

# %%
#temp
plt.scatter(data['temp'],data['cnt'])
plt.xlabel('temp')
plt.ylabel('count')
plt.show()

# %%
#atemp
plt.scatter(data['atemp'],data['cnt'])
plt.xlabel('atemp')
plt.ylabel('count')
plt.show()

# %%
#hum
plt.scatter(data['hum'],data['cnt'])
plt.xlabel('humidity')
plt.ylabel('count')
plt.show()

# %%
#windspeed
plt.scatter(data['windspeed'],data['cnt'])
plt.xlabel('windspeed')
plt.ylabel('count')
plt.show()

# %%
#5. Draw a bar chart for bike sharing data for each month.
sns.countplot(x='mnth',data=data, hue="mnth",palette="Set1")
sns.set(rc={'figure.figsize':(10,6)})
plt.show()

# %%
#6. Draw a pie chart for #5.
data.mnth.groupby(data.mnth).sum().plot(kind='pie')
plt.axis('equal')
plt.show()

# %%
#7. Draw a box plot for bike sharing data, What is your analysis of the box plot.
#mnth
sns.boxplot(x='mnth',y='cnt',data=data)
plt.show()

# %%
#season
sns.boxplot(x='season',y='cnt',data=data)
plt.show()

# %%
#yr
sns.boxplot(x='yr',y='cnt',data=data)
plt.show()

# %%
#holiday
sns.boxplot(x='holiday',y='cnt',data=data)
plt.show()

# %%
#weekday
sns.boxplot(x='weekday',data=data)
plt.show()

# %%
#workingday
sns.boxplot(x='workingday',y='cnt',data=data)
plt.show()

# %%
#weathersit
sns.boxplot(x='weathersit',y='cnt',data=data)
plt.show()

# %%
#8. What is the bike sharing data trend on holidays vs week days? Represent visually through graphs.
#On weekdays bike sharing trend
g = sns.FacetGrid(data,col="weekday", margin_titles=True)
sns.set(rc={'figure.figsize':(8,10)})
g.map(plt.hist, "cnt", color="steelblue")
plt.show()

# %%
#On holidays bike sharing trend
g = sns.FacetGrid(data,col="holiday", margin_titles=True)
sns.set(rc={'figure.figsize':(8,10)})
g.map(plt.hist, "cnt", color="steelblue")
plt.show()

# %%
#9. What is  your analysis  of casual visitors vs registered users? 
data[['casual','registered']].plot()
plt.ylabel("Count")
plt.tight_layout()
plt.show()
#registered people have taken more bikes

# %%
#10. For #9, is there a trend for holidays vs week days
data.boxplot(column='cnt',by=['holiday','weekday'],figsize=(10, 8))
plt.show()

# %%
import numpy as np
import pandas as pd
from sklearn.cross_validation import ShuffleSplit
from sklearn.datasets import load_boston
data = pd.read_csv(r"C:\Users\User\Downloads\insurance.csv")
feature_names=list(data)

# %%
d = pd.DataFrame(data)
d=pd.get_dummies(data)
features=data.drop(['charges','children'], axis = 1)
features=pd.get_dummies(features)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(4, 3))
plt.hist(d.charges)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
for v in features:
    sns.regplot(d[v],d.charges, marker='o', color='blue')
    plt.show()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(features,d.charges)

from sklearn.linear_model import LinearRegression
clf = LinearRegression()
clf.fit(X_train, y_train)
predicted = clf.predict(X_test)
expected = y_test
plt.figure(figsize=(4, 3))
plt.scatter(expected, predicted)
plt.plot([0, 50], [0, 50], '--k')
plt.axis('tight')
plt.xlabel('True charges')
plt.ylabel('Predicted charges')
plt.tight_layout()
plt.show()

# %%
from sklearn.ensemble import GradientBoostingRegressor

clf = GradientBoostingRegressor()
clf.fit(X_train, y_train)

predicted = clf.predict(X_test)
expected = y_test

plt.figure(figsize=(4, 3))
plt.scatter(expected, predicted)
plt.plot([0, 50], [0, 50], '--k')
plt.axis('tight')
plt.xlabel('True charges')
plt.ylabel('Predicted charges')
plt.tight_layout()
plt.show()

# %%
import numpy as np
print("RMS: %r " % np.sqrt(np.mean((predicted - expected) ** 2)))
plt.show()
# Out:
# RMS: 4043.1445902273299

# %%
from sklearn.metrics import r2_score

def performance_metric(y_true, y_predict):
    """ Calculates and returns the performance score between 
        true and predicted values based on the metric chosen. """
    
    # TODO: Calculate the performance score between 'y_true' and 'y_predict'
    score = r2_score(y_true, y_predict)
    
    # Return the score
    return score

# %%
# Calculate the performance of this model
score = performance_metric(predicted,expected)
print ("Model has a coefficient of determination, R^2, of {:.3f}.".format(score))
# Out:
# Model has a coefficient of determination, R^2, of 0.885.
